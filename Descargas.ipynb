# %%
# ==============================
# 🔽 Descargar vuelos TBBR (Flug1_100 y Flug1_104)
#     con sus anotaciones COCO - versión notebook
# ==============================

# Crear carpeta y entrar
# !mkdir -p ~/TBBR && cd ~/TBBR

# Instalar zstd (para descomprimir .tar.zst)
# !sudo apt-get update -y
# !sudo apt-get install -y zstd

# Descargar y extraer los vuelos seleccionados
for ID in [100, 104]:
    print(f"⬇️ Descargando Flug1_{ID}...")
    # !wget -c https://zenodo.org/records/7022736/files/Flug1_{ID}.tar.zst -O Flug1_{ID}.tar.zst

    print(f"📦 Descomprimiendo Flug1_{ID}...")
    # !mkdir -p ~/TBBR/Flug1_{ID}
    # !tar -I zstd -xvf Flug1_{ID}.tar.zst -C ~/TBBR/Flug1_{ID}

    print(f"✅ Flug1_{ID} listo.\n------------------------------------")

# Descargar las anotaciones COCO
for ID in [100, 104]:
    print(f"⬇️ Descargando anotaciones Flug1_{ID}...")
    # !wget -c https://zenodo.org/records/7022736/files/Flug1_{ID}Media_coco.json -O ~/TBBR/Flug1_{ID}Media_coco.json

print("✅ Descarga completa. Verificando tamaño final:")
# !du -sh ~/TBBR
# Out:
# Hit:1 https://deb.debian.org/debian bullseye InRelease
# Hit:2 https://deb.debian.org/debian-security bullseye-security InRelease
# Hit:3 https://download.docker.com/linux/debian bullseye InRelease
# Get:4 https://nvidia.github.io/libnvidia-container/stable/deb/amd64  InRelease [1477 B]
# Hit:5 https://deb.debian.org/debian bullseye-updates InRelease
# Ign:6 https://deb.debian.org/debian bullseye-backports InRelease
# Err:7 https://deb.debian.org/debian bullseye-backports Release
#   404  Not Found [IP: 151.101.2.132 443]
# Hit:8 https://packages.cloud.google.com/apt gcsfuse-bullseye InRelease
# Hit:9 https://packages.cloud.google.com/apt google-compute-engine-bullseye-stable InRelease
# Hit:10 https://packages.cloud.google.com/apt cloud-sdk-bullseye InRelease
# Hit:11 https://packages.cloud.google.com/apt google-fast-socket InRelease
# Hit:12 https://packages.cloud.google.com/apt google-cloud-ops-agent-bullseye-2 InRelease
# Reading package lists... Done
# ...
